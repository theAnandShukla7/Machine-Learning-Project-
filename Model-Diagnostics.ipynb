# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Inches  Ram  Weight        Price  Company_Apple  Company_Asus  \
# 0    13.3    8    1.37   71378.6832           True         False
# 1    13.3    8    1.34   47895.5232           True         False
# 2    15.6    8    1.86   30636.0000          False         False
# 3    15.4   16    1.83  135195.3360           True         False
# 4    13.3    8    1.37   96095.8080           True         False
#
#    Company_Chuwi  Company_Dell  Company_Fujitsu  Company_Google  ...  \
# 0          False         False            False           False  ...
# 1          False         False            False           False  ...
# 2          False         False            False           False  ...
# 3          False         False            False           False  ...
# 4          False         False            False           False  ...
#
#    Gpu_Nvidia Quadro M620  Gpu_Nvidia Quadro M620M  OpSys_Chrome OS  \
# 0                   False                    False            False
# ...

# %%
#Final dataset check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Columns: 338 entries, Inches to OpSys_macOS
# dtypes: bool(334), float64(3), int64(1)
# memory usage: 465.3 KB

# %%
#MODEL DIAGNOSTICS

# %%
#Residuals

# %%
residuals = y - y_pred

# %%
#Residuals vs Predicted

# %%
plt.figure(figsize=(6,5))
plt.scatter(y_pred, residuals, alpha=0.6)
plt.axhline(0, color="red")
plt.xlabel("Predicted Price") , import the value 
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted")
plt.show()

# %%
#Residual distribution

# %%
plt.hist(residuals, bins=30)
plt.title("Residual Distribution")
plt.show()

# %%
#QQ plot (normality check), def the value ( u,v 
import numpy as np 
import pandas as pd,

# %%
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ Plot")
plt.show()

# %%
#Actual vs Predicted

# %%
plt.scatter(y, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
#Residual vs Feature

# %%
plt.scatter(ram, residuals)
plt.axhline(0,color="red")
plt.title("Residual vs RAM")
plt.show()

# %%
importing the def value 
import pandas as pd 
import numpy as np 
regularization the value,
visualization residuals,
<a+b> , import numpy as pd 
import pandas as pd 
#info string the value ,
command prompt , filter
import the value def
